# %%
import numpy as np
import pandas as pd
from icecream import ic
path = 'F://EXCEL Sheets for ADNAN to MERGE 2022//' # to thumbdrive

# %% [markdown]
# Reading in data from Excel files

# %%
A = pd.read_excel(path+'A'+'.xlsx')
ic(A.shape)
A.head()
# Out:
# ic| A.shape: (2439, 25)
#   Letter Font Color Background      Title          First Name Middle  \
# 0      A  NaN   NaN        NaN  Professor              Haider    NaN
# 1      A  NaN   NaN        NaN       Dr.               Sabuur    NaN
# 2      A  NaN   NaN        NaN        Mr.         Abdul-Latif    NaN
# 3      A  NaN   NaN        NaN        Dr.                Asma    NaN
# 4      A  NaN   NaN        NaN       MRs.  Hena and Mr. Ahmad    NaN
#
#               Last Name  Amount Organization  ...  Fax Main Email  \
# 0               Hamoudi     NaN          NaN  ...  NaN        NaN
# 1          Abdul-Kareem     NaN          NaN  ...  NaN        NaN
# 2                 Sawah     NaN          NaN  ...  NaN        NaN
# 3  Mobin-Uddin & Family     NaN          NaN  ...  NaN        NaN
# 4                Masood     NaN          NaN  ...  NaN        NaN
#
#   Secondary Email Additional Email Work/School Email  \
# 0             NaN              NaN               NaN
# 1             NaN              NaN               NaN
# 2             NaN              NaN               NaN
# 3             NaN              NaN               NaN
# 4             NaN              NaN               NaN
#
#                           Street Address        City State Zip Code  \
# 0                       300 Anita Avenue  Pittsburgh    PA    15217
# 1  1295 North Providence Road, Apt. A207       Media    PA    19063
# 2                4142 Bryson Cove Circle      Dublin  Ohio    43016
# 3                        4949 Amber Lane      Dublin  Ohio    43016
# 4                     5710 Aderholt Road      Dublin  Ohio    43016
#
#   Status Notes
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 25 columns]

# %%
B = pd.read_excel(path+'B'+'.xlsx')
ic(B.shape)
B.head()
# Out:
# ic| B.shape: (2827, 17)
#   Letter Color Title    First Name Middle           Last Name  \
# 0      B   Red   Mr.         Aamir    NaN             Shabbir
# 1      B   Red   NaN  Ahlem Zaaeed    NaN  & Ibrahim Alsabbar
# 2      B   Red   Br.         Ajmal    NaN               Kazmi
# 3      B   Red   Ms.       Azeemah    NaN              Kaleem
# 4      B   Red   Sr.       Baheeja    NaN              Waheem
#
#                              Company/Organization  \
# 0                                             NaN
# 1             Move updated 12/28/2019 & 12/6/2020
# 2                                YellowLite Solar
# 3                         Move updated 11/1/2020
# 4  Out of date 12/18/2019; also returned 5/2/2022
#
#                       Street Address           City State    Zip Code  \
# 0           1724 Sperrys Forge Trail       Westlake  Ohio       44145
# 1              X 6202 Somerset Drive  North Olmsted  Ohio  44070-4842
# 2  Do NOT MAIL 1925 St. Clair Avenue      Cleveland  Ohio       44114
# 3         6160 Stumph Road, Apt. 206          Parma  Ohio  44130-1888
# 4           X 632 East Archwood Ave.          Akron  Ohio       44306
#
#                                  Status Unnamed 2 Unnamed 3 Unnamed 4  \
# 0                                   NaN       NaN       NaN       NaN
# 1  move updated 12/20/2018 & 10/16/2019       NaN       NaN       NaN
# 2                                   NaN       NaN       NaN       NaN
# 3                     updated 8/25/2018       NaN       NaN       NaN
# 4                                   NaN       NaN       NaN       NaN
#
#   Unnamed 5 Unnamed 6
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN

# %%
C = pd.read_excel(path+'Mailing List UPDATED 8-14-18 Master with Bad Addresses Included Combo List'+'.xlsx')
ic(C.shape)
C.head()
# Out:
# ic| C.shape: (4238, 15)
#     Color Letter       Title             First Name      Middle  \
# 0  Yellow      C         NaN           Gloria Aisha  Al-Jabouri
# 1     Red      C         NaN          Rubina Saleem         NaN
# 2     Red      C  Dr. & Mrs.  Ademole Kabiru Abiose         NaN
# 3     Red      C        Drs.           Hadele Banna         NaN
# 4     Red      C         NaN         Mohammad Ahmad         NaN
#
#                 Last Name Company  \
# 0                Dominish     NaN
# 1     & Abdul Saleem Khan     NaN
# 2        & Abisola Abiose     NaN
# 3  & Ammar Hindi (REMOVE)     NaN
# 4           & Bilal Ahmad     NaN
#
#                                        Return Status  \
# 0               NOT DELIVERABLE AS ADDRESSED 2-16-18
# 1            RETURNED 12-20-16 (received March 2018)
# 2                         DO NOT MAIL - move uodated
# 3                                       OUT OF STATE
# 4  Move updated 10/23/2020 (back to previous move...
#
#                    Street Address          City State    Zip Code  \
# 0          X 6158 Thunderbird Dr.        Mentor    OH       44060
# 1            X 25445 Highland Rd.    Cleveland     OH  44143-2520
# 2         X 3410 excalibur Avenue      Westlake    OH       44145
# 3          X 4567 Whitehall Drive  South Euclid    OH       44121
# 4  X 6424 Meadow Glen Drive North   Westerville    OH  43082-8268
#
#               Source                              Interfaith Unnamed 1
# 0  Muslim Draft List                                     NaN       NaN
# 1  Muslim Draft List  other old address- 706 Kenbridge Drive       NaN
# 2  Muslim Draft List                                     NaN       NaN
# 3  Muslim Draft List                                     NaN       NaN
# 4  Muslim Draft List                                     NaN       NaN

# %% [markdown]
# Find the unique columns (may appear unnecessary because I've edited the Excel files after this step)

# %%
unique_cols = np.unique(np.concatenate((np.array(A.columns),np.array(B.columns),np.array(C.columns))))
print(unique_cols)
unique_cols.shape
# Out:
# ['Additional Email' 'Additional/Related Contact' 'Amount' 'Background'
#  'City' 'Color' 'Company' 'Company/Organization' 'Fax' 'First Name' 'Font'
#  'Home' 'Interfaith' 'Last Name' 'Letter' 'Main Email' 'Main Phone'
#  'Middle' 'Mobile' 'Organization' 'Return Status' 'Secondary Email'
#  'Source' 'State' 'Status' 'Status Notes' 'Street Address' 'Title'
#  'Unnamed 1' 'Unnamed 2' 'Unnamed 3' 'Unnamed 4' 'Unnamed 5' 'Unnamed 6'
#  'Work' 'Work/School Email' 'Zip Code']
# (37,)

# %% [markdown]
# Now I make a fool of myself trying to combine the sheets

# %%
a = A.sample(10)
b = B.sample(10)
c = C.sample(10)

test = pd.concat([a,b,c])
test.shape
# Out:
# (30, 37)

# %% [markdown]
# Above has the expected dimensions, replicating with bigger datasets:

# %%
merged = pd.concat([A, B, C])
ic([A.shape[0],B.shape[0],C.shape[0]])
ic(merged['Letter'].value_counts())
ic(A.shape[0]+B.shape[0]+C.shape[0])
ic(merged.shape)
# Out:
# ic| [A.shape[0],B.shape[0],C.shape[0]]: [2439, 2827, 4238]
# ic| merged['Letter'].value_counts(): C    4238
#                                      B    2827
#                                      A    2439
#                                      Name: Letter, dtype: int64
# ic| A.shape[0]+B.shape[0]+C.shape[0]: 9504
# ic| merged.shape: (9504, 37)
# (9504, 37)

# %% [markdown]
# Save to Excel file

# %%
merged.to_excel(path+'merged.xlsx')
